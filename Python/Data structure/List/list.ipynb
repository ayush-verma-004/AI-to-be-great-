# %%
fruits = ['orange', 'apple', 'banana', 'cherry', 'date']
fruits.count('banana')
# Out:
# 1

# %%
fruits.index('cherry')
# Out:
# 3

# %%
fruits.index('apple', 1)  # Start searching from index 2
# Out:
# 1

# %%
fruits.reverse()
fruits
# Out:
# ['date', 'cherry', 'banana', 'apple', 'orange']

# %%
fruits.append('grape')
fruits
# Out:
# ['date', 'cherry', 'banana', 'apple', 'orange', 'grape']

# %%
fruits.sort()
fruits
# Out:
# ['apple', 'banana', 'cherry', 'date', 'grape', 'orange']

# %%
fruits.pop()
# Out:
# 'orange'
