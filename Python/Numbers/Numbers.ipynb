# %%
print("Hello")
# This is a simple print statement
# Out:
# Hello

# %%
2 + 2
# This is a simple + operation
# Out:
# 4

# %%
5*6
# This is a simple * operation
# Out:
# 30

# %%
50 - 30
# This is a simple - operation
# Out:
# 20

# %%
12.5 / 100
# This is a simple / operation
# Out:
# 0.125

# %%
17 // 3
# This is a simple // operation. It returns the integer part of the division.
# Out:
# 5

# %%
17 % 3 
# This is a simple % operation. It returns the remainder of the division.
# Out:
# 2

# %%
5 ** 2
# This is a simple ** operation. It returns the exponentiation result.
# Out:
# 25
