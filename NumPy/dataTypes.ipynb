# %%
import numpy as np

# %%
arr = np.array([1, 2, 3, 4, 5])
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
lst = ["string", 1, 2.2, True]
arr = np.array(lst)
arr
# Out:
# array(['string', '1', '2.2', 'True'], dtype='<U32')

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
arr.dtype
# Out:
# dtype('<U32')

# %%
arr = np.array([1, 2, 3, 4, 5], dtype = np.float64)
arr
# Out:
# array([1., 2., 3., 4., 5.])

# %%
arr.dtype
# Out:
# dtype('float64')

# %%
arr = np.array([1, 2, 3, 4, 5])
arr.dtype
# Out:
# dtype('int64')

# %%
new_arr = arr.astype(np.float64)
new_arr
# Out:
# array([1., 2., 3., 4., 5.])
